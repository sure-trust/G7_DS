# %% [markdown]
# <a href="https://colab.research.google.com/github/ushasreepothukunta/G7_DS/blob/main/Mini%20Projects/Usha%20Sree/MOVIE_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Movie_regression.csv")
df
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %% [markdown]
# **EDA**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
df.describe()
# Out:
#        Marketing expense  Production expense  Multiplex coverage  \
# count         506.000000          506.000000          506.000000
# mean           92.270471           77.273557            0.445305
# std           172.030902           13.720706            0.115878
# min            20.126400           55.920000            0.129000
# 25%            21.640900           65.380000            0.376000
# 50%            25.130200           74.380000            0.462000
# 75%            93.541650           91.200000            0.551000
# max          1799.524000          110.480000            0.615000
#
#              Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# count    506.000000    506.000000          506.000000           506.000000
# mean   34911.144022    142.074901            8.014002             8.185613
# std     3903.038232     28.148861            1.054266             1.054290
# min    19781.355000     76.400000            3.840000             4.035000
# ...

# %%
df['Time_taken'].fillna(value=df['Time_taken'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
sns.jointplot(x="Twitter_hastags", y="Collection",data=df)

# %%
w=np.percentile(df.Twitter_hastags ,[99])[0]
w
# Out:
# 307.9904

# %%
df[df.Twitter_hastags>w*2]
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 2              20.5458               69.14               0.531  39912.675
# 423           161.0084               91.20               0.386  33902.165
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 2           134.6               7.485                 7.57            7.495
# 423         158.6               8.960                 9.10            8.830
#
#      Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 2              7.515           7.44         547051           NO      147.88
# 423            9.065           7.96         340669           NO      165.36
#
#      Twitter_hastags   Genre  Avg_age_actors  Num_multiplex  Collection
# 2             2022.4  Comedy              38            458       69400
# 423           1622.4   Drama              29            634       26800

# %%
df[df.Twitter_hastags>w*2]=w

# %%
w
# Out:
# 307.9904

# %%
sns.jointplot(x="Twitter_hastags", y="Collection",data=df)

# %%
df=pd.get_dummies(df,columns=["Genre","3D_available"],drop_first=True)

# %%
df
# Out:
#      Marketing expense  Production expense  Multiplex coverage      Budget  \
# 0              20.1264             59.6200              0.4620  36524.1250
# 1              20.5462             69.1400              0.5310  35668.6550
# 2             307.9904            307.9904            307.9904    307.9904
# 3              20.6474             59.3600              0.5420  38873.8900
# 4              21.3810             59.3600              0.5420  39701.5850
# ..                 ...                 ...                 ...         ...
# 501            21.2526             78.8600              0.4270  36624.1150
# 502            20.9054             78.8600              0.4270  33996.6000
# 503            21.2152             78.8600              0.4270  38751.6800
# 504            22.1918             78.8600              0.4270  37740.6700
# 505            20.9482             78.8600              0.4270  33496.6500
#
# ...

# %%
df=df.drop(['3D_available_NO'], axis=1)

# %%
df
# Out:
#      Marketing expense  Production expense  Multiplex coverage      Budget  \
# 0              20.1264             59.6200              0.4620  36524.1250
# 1              20.5462             69.1400              0.5310  35668.6550
# 2             307.9904            307.9904            307.9904    307.9904
# 3              20.6474             59.3600              0.5420  38873.8900
# 4              21.3810             59.3600              0.5420  39701.5850
# ..                 ...                 ...                 ...         ...
# 501            21.2526             78.8600              0.4270  36624.1150
# 502            20.9054             78.8600              0.4270  33996.6000
# 503            21.2152             78.8600              0.4270  38751.6800
# 504            22.1918             78.8600              0.4270  37740.6700
# 505            20.9482             78.8600              0.4270  33496.6500
#
# ...

# %% [markdown]
# test train split

# %%
X=df.loc[:,df.columns!="Collection"]
Y=df["Collection"]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
X_train,X_test,Y_train,Y_test=tts(X,Y,test_size=0.2,random_state=42)

# %% [markdown]
# DECISION TREE REGRESSOR

# %%
from sklearn import tree
Decision=tree.DecisionTreeRegressor(max_depth=6)
Decision.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(max_depth=6)

# %%
y_test_pred=Decision.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_test_pred)
# Out:
# 0.8935072014041903

# %%
# !pip install graphviz

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
dot_data = export_graphviz(Decision, out_file=None, filled=True,feature_names=X_train.columns)
graph = graphviz.Source(dot_data)
graph

# %%
graph.render("decision_tree")
graph.view("decision_tree")
# Out:
# 'decision_tree.pdf'
