# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Loan Prediction Dataset.csv")

# %%
df.shape
# Out:
# (614, 13)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# # We also have categorical values

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().count()
# Out:
# Loan_ID              614
# Gender               614
# Married              614
# Dependents           614
# Education            614
# Self_Employed        614
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           614
# Loan_Amount_Term     614
# Credit_History       614
# Property_Area        614
# Loan_Status          614
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#for cateogoricall values we use getdummies aand then we continue to fillna

# %%
# Calculate the mean of the 'Loan_Amount_Term' column
mean_loan_term = df['Loan_Amount_Term'].mean()

# Fill missing values in 'Loan_Amount_Term' with the mean
df['Loan_Amount_Term'].fillna(mean_loan_term, inplace=True)
# Fill missing values in 'Credit_History' with a specific value (e.g., 0)
df['Credit_History'].fillna(0, inplace=True)
import pandas as pd

# Assuming your DataFrame is called df
# Calculate the mean of the 'LoanAmount' column
mean_loan_amount = df['LoanAmount'].mean()

# Fill missing values in 'LoanAmount' with the mean
df['LoanAmount'].fillna(mean_loan_amount, inplace=True)

'''from sklearn.ensemble import ExtraTreesClassifier

# Create an Extra Trees model
extra_trees = ExtraTreesClassifier(random_state=42)

# Fit the model to your data
extra_trees.fit(X_train, y_train)

# Make predictions
y_pred = extra_trees.predict(X_test)

# Evaluate the model (e.g., accuracy, confusion matrix, classification report)'''
# Out:
# 'from sklearn.ensemble import ExtraTreesClassifier\n\n# Create an Extra Trees model\nextra_trees = ExtraTreesClassifier(random_state=42)\n\n# Fit the model to your data\nextra_trees.fit(X_train, y_train)\n\n# Make predictions\ny_pred = extra_trees.predict(X_test)\n\n# Evaluate the model (e.g., accuracy, confusion matrix, classification report)'

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
sns.countplot(data=df, x='Gender')

plt.title('Count of Applicants by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
sns.displot(df['Married'])
sns.displot(df['Dependents'])
sns.displot(df['Education'])
sns.displot(df['Self_Employed'])
sns.displot(df['Property_Area']) #OR sns.countplot(data=df, x='Property_Area')
sns.displot(df['Loan_Status'])
#categorical_columns = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Credit_History', 'Property_Area', 'Loan_Status']

# %%
#now for numerical values

# %%
sns.displot(df['ApplicantIncome'])
sns.displot(df['CoapplicantIncome'])
sns.displot(df['LoanAmount'])
sns.displot(df['Loan_Amount_Term'])
sns.displot(df['Credit_History'])

# %%
#create new attribute

df['total_income']=df['ApplicantIncome']+df['CoapplicantIncome']
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# Log Transformation: Take the natural logarithm (log) of the data to make the distribution more normal.
#
# ## Standardization: Standardize the data by subtracting the mean and dividing by the standard deviation.

# %%
#log is for standardizing the data

# %%
df['ApplicantIncome_log']=np.log(df['ApplicantIncome'])
sns.distplot(df['ApplicantIncome_log'])


df['CoapplicantIncome_log']=np.log(df['CoapplicantIncome'])
sns.displot(df['CoapplicantIncome_log'],kde=True)
df['Loan_Amount_Term_log']=np.log(df['Loan_Amount_Term'])
sns.displot(df['Loan_Amount_Term_log'],kde=True)
df['LoanAmount_log']=np.log(df['LoanAmount'])
sns.displot(df['LoanAmount_log'],kde=True)
# Out:
# <ipython-input-21-a558ef035564>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome_log'])
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#BELOW IS USING STANDARD SCALAR USING FOR LOOP

# %%
'''import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np

# Columns to apply log transformation and standardization
columns_to_transform = ['CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# Log transformation
for col in columns_to_transform:
    df[col] = np.log1p(df[col])

# Standardization
scaler = StandardScaler()
df[columns_to_transform] = scaler.fit_transform(df[columns_to_transform])'''
# Out:
# "import pandas as pd\nfrom sklearn.preprocessing import StandardScaler\nimport numpy as np\n\n# Columns to apply log transformation and standardization\ncolumns_to_transform = ['CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']\n\n# Log transformation\nfor col in columns_to_transform:\n    df[col] = np.log1p(df[col])\n\n# Standardization\nscaler = StandardScaler()\ndf[columns_to_transform] = scaler.fit_transform(df[columns_to_transform])"

# %%
cols=['Gender','Married','Education','Self_Employed','Property_Area','Dependents','Loan_Status']
df=pd.get_dummies(df,columns=cols,drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Loan_ID                  614 non-null    object
#  1   ApplicantIncome          614 non-null    int64
#  2   CoapplicantIncome        614 non-null    float64
#  3   LoanAmount               614 non-null    float64
#  4   Loan_Amount_Term         614 non-null    float64
#  5   Credit_History           614 non-null    float64
#  6   total_income             614 non-null    float64
#  7   ApplicantIncome_log      614 non-null    float64
#  8   CoapplicantIncome_log    614 non-null    float64
#  9   Loan_Amount_Term_log     614 non-null    float64
#  10  LoanAmount_log           614 non-null    float64
#  11  Gender_Male              614 non-null    uint8
#  12  Married_Yes              614 non-null    uint8
#  13  Education_Not Graduate   614 non-null    uint8
# ...

# %% [markdown]
# # correlations

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-26-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                          ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome                 1.000000          -0.116605    0.565620
# CoapplicantIncome              -0.116605           1.000000    0.187828
# LoanAmount                      0.565620           0.187828    1.000000
# Loan_Amount_Term               -0.045242          -0.059675    0.038801
# Credit_History                  0.006986          -0.058795   -0.034518
# total_income                    0.893037           0.342781    0.620102
# ApplicantIncome_log             0.790532          -0.237900    0.551556
# CoapplicantIncome_log           0.108432           0.711061    0.417763
# ...

# %%
# Set the figure size
plt.figure(figsize=(15, 15))

sns.heatmap(corr, annot=True, cmap='YlGnBu')

# Show the heatmap
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Loan_ID                  614 non-null    object
#  1   ApplicantIncome          614 non-null    int64
#  2   CoapplicantIncome        614 non-null    float64
#  3   LoanAmount               614 non-null    float64
#  4   Loan_Amount_Term         614 non-null    float64
#  5   Credit_History           614 non-null    float64
#  6   total_income             614 non-null    float64
#  7   ApplicantIncome_log      614 non-null    float64
#  8   CoapplicantIncome_log    614 non-null    float64
#  9   Loan_Amount_Term_log     614 non-null    float64
#  10  LoanAmount_log           614 non-null    float64
#  11  Gender_Male              614 non-null    uint8
#  12  Married_Yes              614 non-null    uint8
#  13  Education_Not Graduate   614 non-null    uint8
# ...

# %%
cols=["ApplicantIncome",'CoapplicantIncome','LoanAmount','Loan_Amount_Term','total_income','Loan_ID','CoapplicantIncome_log']
df=df.drop(columns=cols,axis=1)

# %%
  df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Credit_History           614 non-null    float64
#  1   ApplicantIncome_log      614 non-null    float64
#  2   Loan_Amount_Term_log     614 non-null    float64
#  3   LoanAmount_log           614 non-null    float64
#  4   Gender_Male              614 non-null    uint8
#  5   Married_Yes              614 non-null    uint8
#  6   Education_Not Graduate   614 non-null    uint8
#  7   Self_Employed_Yes        614 non-null    uint8
#  8   Property_Area_Semiurban  614 non-null    uint8
#  9   Property_Area_Urban      614 non-null    uint8
#  10  Dependents_1             614 non-null    uint8
#  11  Dependents_2             614 non-null    uint8
#  12  Dependents_3+            614 non-null    uint8
#  13  Loan_Status_Y            614 non-null    uint8
# ...

# %% [markdown]
# Train

# %%
X=df.drop(columns=['Loan_Status_Y'],axis=1)
Y=df['Loan_Status_Y']

# %%
X
# Out:
#      Credit_History  ApplicantIncome_log  Loan_Amount_Term_log  \
# 0               1.0             8.674026              5.886104
# 1               1.0             8.430109              5.886104
# 2               1.0             8.006368              5.886104
# 3               1.0             7.856707              5.886104
# 4               1.0             8.699515              5.886104
# ..              ...                  ...                   ...
# 609             1.0             7.972466              5.886104
# 610             1.0             8.320205              5.192957
# 611             1.0             8.996157              5.886104
# 612             1.0             8.933664              5.886104
# 613             0.0             8.430109              5.886104
#
#      LoanAmount_log  Gender_Male  Married_Yes  Education_Not Graduate  \
# 0          4.986426            1            0                       0
# ...

# %%
from sklearn.model_selection import train_test_split

# Split the data into a training set and a testing set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %% [markdown]
# Model training

# %% [markdown]
# logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Create a logistic regression model
logistic_model = LogisticRegression(random_state=42)

# Fit the model on the training data
logistic_model.fit(X_train, y_train)

# Predict on the test data
y_pred = logistic_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(confusion)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.7402597402597403
# Confusion Matrix:
# [[21 33]
#  [ 7 93]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.39      0.51        54
#            1       0.74      0.93      0.82       100
#
#     accuracy                           0.74       154
#    macro avg       0.74      0.66      0.67       154
# weighted avg       0.74      0.74      0.71       154

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# Create a Decision Tree model with max depth of 3
decision_tree = DecisionTreeClassifier(max_depth=4, random_state=42)

# Fit the model to your data
decision_tree.fit(X_train, y_train)

# Make predictions
y_pred = decision_tree.predict(X_test)

# Evaluate the model (e.g., accuracy, confusion matrix, classification report)


# Evaluate the model (e.g., accuracy, confusion matrix, classification report)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(confusion)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.7597402597402597
# Confusion Matrix:
# [[27 27]
#  [10 90]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        54
#            1       0.77      0.90      0.83       100
#
#     accuracy                           0.76       154
#    macro avg       0.75      0.70      0.71       154
# weighted avg       0.76      0.76      0.75       154

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest model
random_forest = RandomForestClassifier(random_state=42)

# Fit the model to your data
random_forest.fit(X_train, y_train)

# Make predictions
y_pred = random_forest.predict(X_test)

# Evaluate the model (e.g., accuracy, confusion matrix, classification report)
 #Evaluate the model (e.g., accuracy, confusion matrix, classification report)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(confusion)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.7337662337662337
# Confusion Matrix:
# [[22 32]
#  [ 9 91]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.41      0.52        54
#            1       0.74      0.91      0.82       100
#
#     accuracy                           0.73       154
#    macro avg       0.72      0.66      0.67       154
# weighted avg       0.73      0.73      0.71       154

# %% [markdown]
#  Gradient Boosting:

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Create a Gradient Boosting model
gradient_boosting = GradientBoostingClassifier(random_state=42)

# Fit the model to your data
gradient_boosting.fit(X_train, y_train)

# Make predictions
y_pred = gradient_boosting.predict(X_test)

# Evaluate the model (e.g., accuracy, confusion matrix, classification report)

accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(confusion)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.7402597402597403
# Confusion Matrix:
# [[25 29]
#  [11 89]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.46      0.56        54
#            1       0.75      0.89      0.82       100
#
#     accuracy                           0.74       154
#    macro avg       0.72      0.68      0.69       154
# weighted avg       0.73      0.74      0.73       154

# %% [markdown]
# ExtraTrees Classifier:

# %%
from sklearn.ensemble import ExtraTreesClassifier

# Create an Extra Trees model
extra_trees = ExtraTreesClassifier(random_state=42)

# Fit the model to your data
extra_trees.fit(X_train, y_train)

# Make predictions
y_pred = extra_trees.predict(X_test)

# Evaluate the model (e.g., accuracy, confusion matrix, classification report)

accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(confusion)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.6753246753246753
# Confusion Matrix:
# [[20 34]
#  [16 84]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.37      0.44        54
#            1       0.71      0.84      0.77       100
#
#     accuracy                           0.68       154
#    macro avg       0.63      0.61      0.61       154
# weighted avg       0.66      0.68      0.66       154

# %% [markdown]
# ### Conclusion:
# - **The Decision Tree classifier** achieved an accuracy of 75.97%, making it a relatively effective model for the given task.
# - The precision, recall, and F1-score for both classes (0 and 1) are reasonably balanced, with higher values for class 1, indicating good performance in distinguishing between the two classes.
# - The weighted average F1-score is 0.75, suggesting a balanced trade-off between precision and recall.
